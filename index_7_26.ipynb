# %%
datatypes varaibles datatypes in built functions
# Out:
#   File "/tmp/ipykernel_630/4190916689.py", line 1
#     datatypes varaibles datatypes in built functions
#               ^
# SyntaxError: invalid syntax

# %%
a=10
b=20.6
name="data"

# %%
a=10
## except _ other special characters are not allowed
a=10
### while creating variables it should not start with a number

# %%
import keyword
print(keyword.kwlist)

# %%
async=20
# Out:
#   File "/tmp/ipykernel_630/3130871764.py", line 1
#     async=20
#          ^
# SyntaxError: invalid syntax

# %%
#### Reserve words, keywords we cannot use these as variable names
### use the right name for variable instead of using a,b,c like this names should
### be retail,sales,units, trasactions,age,name,geneder

# %%
pip install packagename

# %%
int, float, string

# %%
a=10
print(a)
print(type(a))

# %%
a=10.2
type(a)
# Out:
# float

# %%
name=" data science machine learning "
type(name)
# Out:
# str

# %%
int,float,str
# Out:
# (int, float, str)

# %%
int('name')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_630/3667560212.py in <cell line: 0>()
# ----> 1 int('name')
#
# ValueError: invalid literal for int() with base 10: 'name'

# %%
type conversion:

  int --> float,string
  float ---> int,string
  string cannot be int,float

# %%
float("data")

# %%
type(2+3j)
# Out:
# complex

# %%
a=2+3j
a.real
# Out:
# 2.0

# %%
a.imag
# Out:
# 3.0

# %%
x="data science"

# %%
x
# Out:
# 'data science'

# %%
x="data engineering"
print(x)
# Out:
# data engineering

# %%
x[-4:-2]
# Out:
# 'ri'

# %%
x
# Out:
# 'data engineering'

# %%
print(x[-11:])
print(x[:4])
# Out:
# engineering
# data

# %%
x[-11:4]
# Out:
# ''

# %%
len(x)
x[20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_630/3271376848.py in <cell line: 0>()
#       1 len(x)
# ----> 2 x[20]
#
# IndexError: string index out of range

# %%
text = "Edukron Data Science and Data Engineering Batch 2026"
#print(text[-27:-11])
#print(text[-22:-11])
#print(text[-10:-5])
#print(text[-4:])
print(text[-39:-22])
print(text[-44:-5])

# %%
text = "Edukron Data Science and Data Engineering Batch 2026"
#print(text[25:41])
#print(text[30:41])
#print(text[42:47])
print(text[48:52])
print(text[13:29])
print(text[8:47])

# %%
a = "data"
a.replace("da","DA")
print(a[0:2].upper()+a[2:])
# Out:
# DAta

# %%
x = "data science"
y= "machine Learning"
#z =x[0:4]+y[7:]
x[0:4].center(12,"*")+y[8:].ljust(12,"*")
# Out:
# '****data****Learning****'

# %% [markdown]
# ```python
# text = "Edukron Data Science and Data Engineering Batch 2026"
# ```
#
# # Python String Indexing Questions
#
# 1. Write the indexing expression to print **"Edukron"**.
#    ```
#    Answer:
#    print(text[0:7])
#    print(text[-52:-45])
#    print(text[:-45])
#    ```
#
# 2. Write the indexing expression to print **"Data"** (first occurrence).
#    ```
#    Answer:
#    print(text[-44:-40])
#    print(text[8:12])
#    ```
#
# 3. Write the indexing expression to print **"Science"**.
#    ```
#    Answer:
#    print(text[13:21])
#    print(text[-39:-32])
#    ```
#
# 4. Write the indexing expression to print **"and"**.
#    ```
#    Answer:
#    print(text[-31:-28])
#    print(text[21:24])
#    ```
#
# 5. Write the indexing expression to print **"Data Engineering"**.
#    ```
#    Answer:print(text[-27:-11])
#    print(text[25:41])
#    ```
#
# 6. Write the indexing expression to print **"Engineering"**.
#    ```
#    Answer:print(text[-22:-11])
#    print(text[30:41])
#    ```
#
# 7. Write the indexing expression to print **"Batch"**.
#    ```
#    Answer:print(text[-10:-5])
#    print(text[42:47])
#    ```
#
# 8. Write the indexing expression to print **"2026"**.
#    ```
#    Answer:print(text[-4:])
#    print(text[48:52])
#    ```
#
# 9. Write the indexing expression to print **"Science and Data"**.
#    ```
#    Answer:print(text[-39:-22])
#    print(text[13:29])
#    ```
#
# 10. Write the indexing expression to print **"Data Science and Data Engineering Batch"**.
#     ```
#     Answer:
#     print(text[-44:-5])
#     print(text[8:47])
#     ```
# ```
